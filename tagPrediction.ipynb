# %% [markdown]
# Nosso problema é um problema de classificação de multi-label em que pretendemos prever as tags relevantes para uma determinada pergunta com base em seu título e corpo. O objetivo é atribuir uma ou mais tags a cada pergunta com precisão. Essa é uma tarefa essencial para plataformas on-line de resposta a perguntas, como o Stack Overflow, em que milhões de perguntas são publicadas diariamente, e torna-se cada vez mais difícil para os usuários encontrar perguntas relevantes para responder ou ler.
#
# O problema é desafiador porque uma única pergunta pode ter várias tags relevantes, o que a torna um problema de classificação de multi-label. Além disso, as perguntas no Stack Overflow podem ser altamente técnicas, e a mesma palavra pode ter significados diferentes dependendo do contexto, o que torna difícil prever com precisão as tags relevantes. Portanto, precisamos pré-processar os dados, identificar os recursos importantes e usar técnicas adequadas de aprendizado de máquina para resolver esse problema com precisão.
#
# Os insights obtidos com esse problema podem ajudar a melhorar a experiência do usuário em plataformas on-line de perguntas e respostas, sugerindo tags relevantes para a pergunta, o que facilita para os usuários encontrarem as respostas de que precisam. Além disso, ele pode ajudar as comunidades on-line a organizar e categorizar melhor suas perguntas, facilitando a navegação por elas.

# %%
# O problema que estamos tentando resolver é o de predição de tags para perguntas do StackOverflow.

# %%
#%pip install contractions

# %%
import pandas as pd

# %%
# carregando os dados
questions_df = pd.read_csv('data/Questions.csv', encoding="ISO-8859-1", usecols =['Id','Score', 'Title', 'Body'])
questions_df = questions_df.sample(n=20000)

# %%
# Cleaning the data
import re
import string
import contractions
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

def normalize_text(s):
    s = s.lower()
    return s

def remove_html_tags(text):
    text = re.sub('<pre>.*?</pre>', '', text, flags=re.DOTALL)
    text = re.sub('<code>.*?</code>', '', text, flags=re.DOTALL)
    text = re.sub('<[^>]+>', '', text, flags=re.DOTALL)
    return text.replace("\n", "")

def remove_punctuation(text):
    res = text.split()
    for word in res:
        if word in string.punctuation:
            res.remove(word)
    return ' '.join(res) 

def remove_contractions(text):
    return contractions.fix(text)

def lemmatize(text):
    lemmatizer = WordNetLemmatizer()
    return ' '.join([lemmatizer.lemmatize(w) for w in word_tokenize(text)])

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    return ' '.join([w for w in word_tokenize(text) if not w in stop_words])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Danilo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
questions_df['Body'] = questions_df['Body'].apply(remove_html_tags)
questions_df['Body'] = questions_df['Body'].apply(remove_contractions)
questions_df['Body'] = questions_df['Body'].apply(normalize_text)
questions_df['Body'] = questions_df['Body'].apply(remove_stopwords)
questions_df['Body'] = questions_df['Body'].apply(remove_punctuation)
questions_df['Body'] = questions_df['Body'].apply(lemmatize)
questions_df['Title'] = questions_df['Title'].apply(remove_html_tags)
questions_df['Title'] = questions_df['Title'].apply(remove_contractions)
questions_df['Title'] = questions_df['Title'].apply(normalize_text)
questions_df['Title'] = questions_df['Title'].apply(remove_stopwords)
questions_df['Title'] = questions_df['Title'].apply(remove_punctuation)
questions_df['Title'] = questions_df['Title'].apply(lemmatize)

# %%
# Print the first rows of `questions_df`
print(questions_df.head())
# Out:
#               Id  Score                                              Title
# 724361  24625620      3  http server respond head request chunked encoding  \
# 735150  24964840      0                  io uitextview wrapping every line
# 7232      490040      0                 nhibernate evicting object session
# 469140  16411980      1  calling angular controller function external j...
# 882884  29560870      3                             azure busy worker role
#
#                                                      Body
# 724361  question http server response look like head s...
# 735150  pretty sure data source funky \p element seein...
# 7232    mapping productcategory tree using fluent nhib...
# 469140  user click word displaypopup ) called create a...
# 882884  microsoft azure project project deploy 3 cloud...

# %%
def join_strings(x):
    return " ".join(x)


# Load the tags dataset
tags_df = pd.read_csv("data/Tags.csv", encoding="ISO-8859-1", dtype={'Tag': str})
tags_df['Tag'] = tags_df['Tag'].astype(str)

tags_group = tags_df.groupby("Id")['Tag'].apply(join_strings)
tags = pd.DataFrame({'Id':tags_group.index, 'Tags':tags_group.values})

# %%
tags
# Out:
#                Id                                            Tags
# 0              80                         flex actionscript-3 air
# 1              90    svn tortoisesvn branch branching-and-merging
# 2             120                             sql asp.net sitemap
# 3             180  algorithm language-agnostic colors color-space
# 4             260         c# .net scripting compiler-construction
# ...           ...                                             ...
# 1264211  40143210                                   php .htaccess
# 1264212  40143300                                 google-bigquery
# 1264213  40143340                          android android-studio
# 1264214  40143360                               javascript vue.js
# 1264215  40143380                                 npm mocha babel
#
# [1264216 rows x 2 columns]

# %%
merged_df = pd.merge(questions_df, tags, on='Id')

# %%
# For y we need the order of tags to not affect the result, so we use an encoder to transform the tags into numbers
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(merged_df['Title'] + ' ' + merged_df['Body'])

mlb = MultiLabelBinarizer(sparse_output=True)

y = mlb.fit_transform(merged_df['Tags'].str.split(" "))

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# Training the model for a multilabel classification, using a OneVsRestClassifier with a LogisticRegression and knowing that the data is sparse
# We need the 4 most probable tags for each question, so we use predict_proba instead of predict

from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='lbfgs')
clf = OneVsRestClassifier(lr)

clf.fit(X_train, y_train)
# Out:
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 0 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 10 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 12 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 13 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 14 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 29 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 41 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 62 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 68 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 70 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 78 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 90 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 92 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 94 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 96 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 99 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 107 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 114 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 118 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 119 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 123 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 132 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 159 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 162 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 180 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 186 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 196 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 215 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 219 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 220 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 227 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 230 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 239 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 248 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 249 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 266 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 276 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 277 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 294 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 300 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 335 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 336 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 350 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 363 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 366 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 373 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 375 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 384 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 385 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 408 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 450 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 468 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 470 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 471 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 484 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 490 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 491 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 495 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 496 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 497 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 505 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 507 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 508 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 514 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 517 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 524 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 531 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 532 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 538 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 546 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 547 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 551 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 553 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 556 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 564 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 566 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 568 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 571 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 579 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 584 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 590 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 601 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 606 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 613 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 619 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 626 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 630 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 632 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 634 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 644 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 646 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 653 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 655 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 661 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 663 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 683 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 684 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 695 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 714 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 716 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 729 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 737 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 738 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 739 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 740 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 742 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 755 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 758 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 767 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 769 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 774 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 775 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 778 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 779 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 781 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 784 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 785 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 786 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 789 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 790 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 794 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 804 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 808 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 811 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 826 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 832 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 839 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 843 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 845 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 850 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 851 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 863 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 871 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 877 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 879 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 884 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 885 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 886 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 898 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 933 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 935 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 938 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 952 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 957 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 977 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 983 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 989 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 991 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1013 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1014 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1023 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1026 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1053 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1055 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1059 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1064 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1077 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1082 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1088 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1089 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1097 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1108 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1116 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1122 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1136 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1151 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1157 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1158 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1162 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1172 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1173 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1175 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1179 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1181 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1184 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1191 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1197 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1209 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1211 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1213 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1217 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1219 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1226 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1231 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1233 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1234 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1236 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1237 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1245 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1275 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1279 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1286 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1293 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 1297 is present in all training examples.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7891 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7892 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7911 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7919 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7920 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7928 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7933 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7942 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7959 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7965 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7966 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7967 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7969 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7975 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7990 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 7993 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8004 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8005 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8023 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8036 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8045 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8047 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8076 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8079 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8083 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8084 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8095 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8097 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8107 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8108 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8117 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8144 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8151 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8161 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8167 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8172 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8180 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8187 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8193 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8196 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8203 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8224 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8231 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8234 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8243 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8246 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8247 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8261 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8264 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8267 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8268 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8284 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8287 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8294 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8315 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8329 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8339 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8356 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8363 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8364 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8365 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8368 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8395 is present in all training examples.
#   warnings.warn(
# C:\Users\Danilo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\multiclass.py:77: UserWarning: Label not 8397 is present in all training examples.
#   warnings.warn(
# OneVsRestClassifier(estimator=LogisticRegression())

# %%
y_pred = clf.predict_proba(X_test)

# %%
# Display the 4 most probable tags for each question, store the predicted tags and compare them with the real tags
import numpy as np

# We need to sort the tags by probability in descending order
real_tags = mlb.inverse_transform(y_test)
tags_index_probability = np.argsort(y_pred, axis=1)[:, -4:]
predicted_tags = mlb.classes_[tags_index_probability]

for i in range(10):
    print("Title:\n", merged_df['Title'].iloc[i])
    print("Body:\n", merged_df['Body'].iloc[i])
    print("Predicted tags:\n", predicted_tags[i])
    print("Real tags:\n", real_tags[i])
    print("\n")
# Out:
# Title:
#  http server respond head request chunked encoding
# Body:
#  question http server response look like head sent resource server decided perform chunked encoding server always wish perform chunked encoding get specific resource know exact content-length generating response server behave head sent resource
# Predicted tags:
#  ['java' 'c++' 'c#' 'android']
# Real tags:
#  ('xamarin',)
#
#
# Title:
#  io uitextview wrapping every line
# Body:
#  pretty sure data source funky \p element seeing lot wrapping text uitextview apparent reason text wrap console missing something uitextview property
# Predicted tags:
#  ['python' 'mysql' 'sql-server' 'sql']
# Real tags:
#  ('sqlalchemy', 'sql', 'database')
#
#
# Title:
#  nhibernate evicting object session
# Body:
#  mapping productcategory tree using fluent nhibernate everything going fine tried walk tree returned database ensure saving retreiving appropriately.here testing instantiate 4 category beverage beer light beer dark beeradd beer beverage light beer dark beer beer.save beverage cascade set alldeleteorphan flush session persists entire treeevict productcategories sessionload beverage databasecheck loaded object fromdb equalto sameas beverages.check fromdb one child productcategorycheck child fromdb equalto sameas beerthe test fails child sameas beer mean actually loading object database still nhibernate session somewhere.any insight much appreciated.edit response sean 's comment using memory sqlite database soon session/connections closed database blown away
# Predicted tags:
#  ['php' 'jquery' 'html' 'javascript']
# Real tags:
#  ('html', 'javascript', 'php', 'searchbar')
#
#
# Title:
#  calling angular controller function external javascript
# Body:
#  user click word displaypopup ) called create angular app shoot data scope . apply function data showing popup call scope.test ) anything function update app get call method ? application definition
# Predicted tags:
#  ['android' 'javascript' 'c#' 'java']
# Real tags:
#  ('java', 'java-ee', 'db2', 'websphere-commerce')
#
#
# Title:
#  azure busy worker role
# Body:
#  microsoft azure project project deploy 3 cloud services.i 2 different environment one test one production.i problem deployment test environment recently impossible deploy one service production.here error visual studio 11:42:49 instance 0 role test-worker busy detail starting role ... system initialized successfully [ 2015-04-10t09:42:26z last role error exit code 0 exit time [ 2015/04/10 09:42:27.927 11:44:55 instance 0 role test1-worker busy detail starting role ... system initialized successfully [ 2015-04-10t09:44:29z last role error exit code 0 exit time [ 2015/04/10 09:44:31.401 11:44:55 instance 0 role test-worker busy detail initializing role ... system initialized successfully [ 2015-04-10t09:44:47z last role error exit code 0 exit time [ 2015/04/10 09:44:49.006 11:47:03 instance 0 role test1-worker restarting detail role encountered error stopped system initialized successfully [ 2015-04-10t09:46:45z last role error exit code 0 exit time [ 2015/04/10 09:46:47.623 11:47:03 instance 0 role test-worker busy detail waiting role start ... system initialized successfully [ 2015-04-10t09:46:58z last role error exit code 0 exit time [ 2015/04/10 09:47:00.230 11:49:07 instance 0 role test1-worker restarting detail role encountered error stopped system initialized successfully [ 2015-04-10t09:48:55z last role error exit code 0 exit time [ 2015/04/10 09:48:57.005 11:49:07 instance 0 role test-worker busy detail waiting role start ... system initialized successfully [ 2015-04-10t09:48:58z last role error : exit code 0 exit time [ 2015/04/10 09:49:00.647 check azure console see indeed worker instance busy.recently updated azure sdk2.5 work test environment sure problem guess
# Predicted tags:
#  ['javascript' 'android' 'objective-c' 'ios']
# Real tags:
#  ('google-analytics', 'ios')
#
#
# Title:
#  ios- two singleton class name 'sharedobj
# Body:
#  added two singleton class b object string a1 b object string b1 used crash saying bobj type ' ' object b1 gave different name .i need know happened object name class level thanks .
# Predicted tags:
#  ['javascript' 'php' 'c#' 'java']
# Real tags:
#  ('apache-camel',)
#
#
# Title:
#  use call_user_func_array mysqli_stmt object
# Body:
#  writing wrapper class mysqli writing function accept query variable number parameter invoke code calling function run code , get warning ?
# Predicted tags:
#  ['c++' 'javascript' 'java' 'c#']
# Real tags:
#  ('perl', 'moose')
#
#
# Title:
#  memory leak autoreleased nsdictionary
# Body:
#  profiled code profiler show one method leaking memory object autoreleased snippet relevant code see sourcearray episode alloc 'd memory autoreleased episode array added sourcearray array sourcearray becomes object passed caller.the specific information provided profiler responsible library `` foundation `` responsible caller [ nsdictionary nsdictionary newwithcontentsof immutable . expand eventually point app responsible library method responsible caller.since autoreleased array profiler complaining leaked memory
# Predicted tags:
#  ['jquery' 'wordpress' 'html' 'php']
# Real tags:
#  ('hyperlink', 'php', 'image-gallery', 'advanced-custom-fields', 'wordpress')
#
#
# Title:
#  sqlite3 query response slow
# Body:
#  following query give right result cost 3 second pretty slow processing result optimization technique applied query improve performance/response time say lt 1sec.schemaexplain query plan
# Predicted tags:
#  ['jquery' 'html' 'javascript' 'php']
# Real tags:
#  ('gravity-forms-plugin', 'php')
#
#
# Title:
#  android kenburneffect issue
# Body:
#  issue related kenburnseffect library.in library set image remote url .. like .. work perfectly.but project need set image folder .. reference drawable url string used implementation like ... work .. show blank screen exception nothing.i understand issue ... please help ..
# Predicted tags:
#  ['asp.net-mvc' 'c#' 'ruby-on-rails' 'php']
# Real tags:
#  ('asp.net-mvc-4',)

# %%
# Find the index of each tag in real tags in the predicted tag, taking into account that the tags are sorted by probability
def find_index(real_tags, predicted_tags):
    indexes = []
    for i in range(len(real_tags)):
        indexes.append([])
        for tag in real_tags[i]:
            res = np.where(predicted_tags[i] == tag)
            if res[0].size > 0:
                indexes[i].append(res[0][0])
    return indexes

# Calculate the accuracy of the model
def accuracy(real_tags, predicted_tags):
    indexes = find_index(real_tags, predicted_tags)
    #calculate the accuracy by how many tags were predicted correctly
    return sum([1 for i in range(len(indexes)) if len(indexes[i]) > 0]) / len(indexes)

# %%
accuracy(real_tags, predicted_tags)
# Out:
# 0.7296

# %%
# Frequência das tags reais
from collections import Counter

real_tags_list = [tag for tags in real_tags for tag in tags]
Counter(real_tags_list).most_common(10)
# Out:
# [('javascript', 480),
#  ('java', 420),
#  ('php', 393),
#  ('c#', 384),
#  ('android', 365),
#  ('jquery', 318),
#  ('python', 271),
#  ('html', 243),
#  ('c++', 190),
#  ('mysql', 186)]

# %%
# Frequência das tags em predicted_tags
from collections import Counter

predicted_tags_list = [tag for tags in predicted_tags for tag in tags]
Counter(predicted_tags_list).most_common(10)
# Out:
# [('c#', 2869),
#  ('java', 2791),
#  ('javascript', 2558),
#  ('php', 1493),
#  ('android', 1128),
#  ('c++', 1036),
#  ('jquery', 854),
#  ('html', 825),
#  ('python', 800),
#  ('ios', 621)]

# %% [markdown]
# A acurácia é testada com as 4 tags mais prováveis, mas podemos testar com as 3, 2 ou 1 mais provável. Esse método de acurácia de apliquei se remete a um tipo de acurácia que é usada em problemas de classificação multiclasse, onde se considera que o modelo acertou se ele acertou pelo menos uma das classes
# Esse tipo de teste é mais adequado para o nosso problema, pois se o modelo acertar pelo menos uma das tags, já é um bom resultado, o usuário pode ter por exemplo sugestões de tags para completar a pergunta no stack oveflow, e não necessariamente todas as tags que ele queria.
#
# Mesmo assim, seria melhor a acurácia ser mais próximo do 100%, o fato de que o calculo da acurácia ser calculado pela presença de pelo menos uma tag correta já infla o numero de acerto, e para esse tipo era esperado algo perto da perfeição. Por isso há algumas suspeitas sobre o que pode ter causado baixa precisão, por exemplo dados desbalanceados, se o número de exemplos para cada tag for desbalanceado, o modelo poderá não aprender a prever com precisão as tags menos frequentes. Isso pode levar a uma baixa precisão para essas tags. E no nosso caso, pegando apenas uma porcentagem pequena (por motivos de performance) acarretou a varias tags não serem inclusas no treino ou nos testes. Ambiguidade nos dados, pode ser difícil fazer tags com precisão em algumas perguntas, pois elas estão relacionadas a vários tópicos. Nesses casos, o modelo pode ter dificuldade para escolher a tag correta.
#
# Com base na análise da frequência das tags, podemos ver que as tags mais comuns nos dados reais são javascript, java, php, c# e android. Por outro lado, nas tags preditas, vemos que as tags mais comuns são c#, java, javascript, php e android. Isso sugere que o modelo é capaz de capturar as tags mais comuns nos dados reais até certo ponto, mas não é capaz de capturar as tags menos frequentes também.
# Isso não é surpreendente, pois o modelo foi treinado em um número limitado de tags e é difícil generalizar para tags novas e menos frequentes. Também é possível que o modelo não tenha conseguido captar as nuances das tags menos frequentes devido ao número limitado de exemplos para cada tag nos dados de treinamento.
# Entretanto, vale a pena observar que o modelo conseguiu identificar algumas tags menos frequentes, como "nhibernate" e "sqlalchemy", que não estavam entre as tags mais frequentes nos dados reais. Isso sugere que o modelo tem alguma capacidade de generalizar para tags menos frequentes, mas certamente há espaço para melhorias nessa área.
