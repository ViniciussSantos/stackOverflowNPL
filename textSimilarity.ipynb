# %% [markdown]
# Uma das maiores reclamações de usuários do stackOverflow é a quantidade de perguntas duplicadas, um problema que diminui a qualidade do site. Através de técnicas de NLP, queremos entender se perguntas duplicadas são realmente um problema.

# %%
import pandas as pd

# %%
# carregando os dados
questions_df = pd.read_csv('data/Questions_sample.csv', encoding="ISO-8859-1", usecols =['Id','Score', 'Title', 'Body'])

# %%
questions_df.head(10)
# Out:
#          Id  Score                                              Title
# 0  37914700      1  How to assign variable inside of the string in...  \
# 1  26870250      1       Server not receiving in socket communication
# 2  20454920      0        HTML tag input text line-height not working
# 3   6731940      0               Message Sent to Deallocated Instance
# 4  28003210      3  Need SQL help ranking users by combining data ...
# 5  20542020      0             popen Hangs and cause CPU usage to 100
# 6  31910720      0  Is it possible to set default ttl for all keys...
# 7  10281700      0  Validating that each project imports our Commo...
# 8  27214890      1  Search for two specific elements in multidimen...
# 9   9420130      1  Loading a particular frame in Delphi 6 causes ...
#
#                                                 Body
# 0  <p>I wanna store sql query in XML and execute ...
# 1  <p>I'm trying to make a Java program in which ...
# 2  <p>I have this :</p>\n\n<pre><code>&lt;form me...
# 3  <p>I'm using TouchXML to parse an element in i...
# 4  <p>users</p>\n\n<pre><code>   id  | first_name...
# 5  <p>I have a code that use popen to execute a s...
# 6  <p>I've read redis config <a href="https://raw...
# 7  <p>I run a fairly-large team (5 solutions, ~15...
# 8  <p>consider the following vector</p>\n\n<pre><...
# 9  <p>I have a frame that never had any problems ...

# %%
questions_df.tail(10)
# Out:
#              Id  Score                                              Title
# 19990   8894560      2     mySql to get last records of duplicate entries  \
# 19991  24492600      2                      Search in numpy object arrays
# 19992  30974440      1  Rarely occurring ConcurrentModificationExcepti...
# 19993  35253200      0             Typescript move code to multiple files
# 19994   1303560      0                 Jquery Fade out Transparency In IE
# 19995  16499640      0                          GAE datastore put and get
# 19996  12738910      0   Rotating Image script not keeping preset classes
# 19997  18043500      1  Why does time difference measurement with `std...
# 19998  30372760      0  How to change background of non-visible button...
# 19999   2757040      0  RPC for java/python with rest support, HTML mo...
#
#                                                     Body
# 19990  <blockquote>\n  <p><strong>Possible Duplicate:...
# 19991  <p>I've got a <strong>Numpy Object Array</stro...
# 19992  <p>Sometimes i'm experiencing the following ex...
# 19993  <p>I have code like that in my <code>app.ts</c...
# 19994  <p>I'm working on a site and I have run into a...
# 19995  <p>Hi I'm just playing around with the datasto...
# 19996  <p>Im using a script to rotate through various...
# 19997  <p>I measured several time differences by usin...
# 19998  <p>My code works only for visible views. </p>\...
# 19999  <p>Here's my set of requirements: I'm looking ...

# %%
# limpando os dados
import re
import string
import contractions

def normalize_text(s):
    s = s.lower()
    return s

def remove_html_tags(text):
    text = re.sub('<pre>.*?</pre>', '', text, flags=re.DOTALL)
    text = re.sub('<code>.*?</code>', '', text, flags=re.DOTALL)
    text = re.sub('<[^>]+>', '', text, flags=re.DOTALL)
    return text.replace("\n", "")

def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)    

def remove_contractions(text):
    return contractions.fix(text)

# %%
questions_df['Body'] = questions_df['Body'].apply(remove_html_tags)
questions_df['Body'] = questions_df['Body'].apply(remove_contractions)
questions_df['Body'] = questions_df['Body'].apply(normalize_text)
questions_df['Title'] = questions_df['Title'].apply(remove_html_tags)
questions_df['Title'] = questions_df['Title'].apply(remove_contractions)
questions_df['Title'] = questions_df['Title'].apply(normalize_text)

# %% [markdown]
# Com os dados limpos, podemos começar a fazer uma analise de similaridade entre as perguntas.

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/vini/.local/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/vini/.local/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/vini/.local/lib/python3.8/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/vini/.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/vini/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Nesta função, vamos calcular a similaridade entre as perguntas. Para isso, vamos usar a biblioteca sklearn, que possui uma função chamada cosine_similarity, que calcula a similaridade entre dois vetores. Para obter esses vetores, vamos usar a biblioteca TfidfVectorizer, que transforma uma lista de documentos em uma matriz de termos de frequência inversa.
#
# criamos uma nova coluna chamada similarTo, que vai conter um dict com o id da pergunta e a similaridade entre elas. Se não encontrarmos nenhum resultado, a similarTo vai ser um dict vazio.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


def find_similar_questions(df, threshold):
    # Create a vectorizer to convert the text data into numerical vectors
    vectorizer = TfidfVectorizer(stop_words='english')
    
    # Convert the text data into vectors
    vectors = vectorizer.fit_transform(df['Title'] + ' ' + df['Body'])
    
    # Compute the pairwise cosine similarity matrix between all questions
    cosine_sim = cosine_similarity(vectors)
    
    # Initialize an empty list to store the similar questions for each question
    similar_to_values = []
    
    # Iterate over each question
    for question in df.itertuples():
        # Get the index and ID of the current question
        i = question.Index
        question_id = question.Id
        
        # Get the similarity scores of the current question with all other questions
        similarity_scores = list(enumerate(cosine_sim[i]))
        
        # Remove the similarity score of the current question with itself
        similarity_scores = [(j, score) for j, score in similarity_scores if j != i]
        
        # Sort the similarity scores in descending order
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
        
        # Filter the similarity scores by the threshold
        similar_scores = [(df.iloc[j]['Id'], score) for j, score in similarity_scores if score >= threshold]
        
        # If the current question has similar questions above the threshold
        if similar_scores:
            # Add the similar questions to the list
            similar_questions = {j: score for j, score in similar_scores}
            similar_to_values.append(similar_questions)
        else:
            # If the current question has no similar questions above the threshold, add an empty dictionary to the list
            similar_to_values.append({})
    
    # Add the similar questions list as a new column to the DataFrame
    df['SimilarTo'] = similar_to_values
    
    return df

# %%
# (demora mais de 2 minutos)
similar_questions_df = find_similar_questions(questions_df, 0.7)

# %%
similar_questions_df.head(10)
# Out:
#          Id  Score                                              Title
# 0  37914700      1  how to assign variable inside of the string in...  \
# 1  26870250      1       server not receiving in socket communication
# 2  20454920      0        html tag input text line-height not working
# 3   6731940      0               message sent to deallocated instance
# 4  28003210      3  need sql help ranking users by combining data ...
# 5  20542020      0           popen hangs and because cpu usage to 100
# 6  31910720      0  is it possible to set default ttl for all keys...
# 7  10281700      0  validating that each project imports our commo...
# 8  27214890      1  search for two specific elements in multidimen...
# 9   9420130      1  loading a particular frame in delphi 6 causes ...
#
#                                                 Body SimilarTo
# 0  i want to store sql query in xml and execute i...        {}
# 1  i am trying to make a java program in which th...        {}
# 2  i have this :very simple.the text is in the md...        {}
# 3  i am using touchxml to parse an element in ios...        {}
# 4  usersservice1service2here is what my result wo...        {}
# 5  i have a code that use popen to execute a scri...        {}
# 6  i have read redis config document but cannot f...        {}
# 7  i run a fairly-large team (5 solutions, ~150 p...        {}
# 8  consider the following vectorwhich is a three ...        {}
# 9  i have a frame that never had any problems bef...        {}

# %%
filtered_similar_questions_df = similar_questions_df.loc[similar_questions_df['SimilarTo'] != {}]
filtered_similar_questions_df.head(15)
# Out:
#             Id  Score                                              Title
# 61     9154270      1                   vim move line up,down,left,right  \
# 222   22959390      0         i have a questions regarding matlab matrix
# 1110  30419690      3                 cutting posixlt types by hour in r
# 1171  18515230      7           javascript map in leaflet how to refresh
# 1559   9396590      9                        is md5 decryption possible?
# 1732  14834780     16     relation between akka and scala.actors in 2.10
# 1830  19772820      0            error handling when reading from buffer
# 2089  24158810      0    kohana 3.1 create imagejpeg or imagepng captcha
# 2414  16050620      0  call external page & load dynamic content into...
# 2966   9533830      0       sinatra rack middleware hijacks '/' root url
# 3865  30362580      0        finding the sql statements for a given linq
# 4122   6190620     14                   how to convert linq query to sql
# 4145   9714150      0  magento configurable items - multiple store vi...
# 5025   9058890      0           gcc on mac osx--multiple versions of gcc
# 6292   8016520      3    choosing gcc version when building ( setup.py )
#
#                                                    Body
# 61    in netbeans with ctrl+left, ctrl+up, ctrl+righ...  \
# 222   suppose i have this matrix:i want this matrix ...
# 1110  suppose i have the following datawhat i am try...
# 1171  i have a basic geojson program in javascript b...
# 1559    possible duplicate:  is it possible to decry...
# 1732  the scala 2.10 release notes says this:  "akka...
# 1830  i have a tablet sending a 5 byte message to a ...
# 2089  i am trying to put a simple captcha in kohana ...
# 2414  well, i understand there is a way to change co...
# 2966  i am trying to use a sinatra app as middleware...
# 3865  i am using linq lambda expressions extensively...
# 4122  just trying to get the sql that is generated b...
# 4145  i am running magento enterprise 1.11.2.0 and m...
# 5025  i think i have several versions of gcc install...
# 6292  i am trying to build a python module (scikit.t...
#
#                                               SimilarTo
# 61                       {23025930: 0.7233997503802955}
# 222   {10901520: 0.7192533941946715, 17597310: 0.710...
# 1110  {28018320: 0.7409016313750877, 30072410: 0.730...
# 1171                     {27646070: 0.7168251160581205}
# 1559                      {8910050: 0.7004291615260755}
# 1732  {9714150: 0.9562011319016563, 21018500: 0.8471...
# 1830                     {30072410: 0.7260943092325658}
# 2089                     {10632520: 0.8351285685110357}
# 2414                     {16007330: 0.7697189645496809}
# 2966                     {39895110: 0.7125851373919012}
# 3865                      {6190620: 0.7072100150360668}
# 4122                     {30362580: 0.7072100150360668}
# 4145  {14834780: 0.9562011319016563, 21018500: 0.878...
# 5025                      {8016520: 0.7468263985306434}
# 6292                      {9058890: 0.7468263985306434}

# %%
filtered_similar_questions_df.tail(15)
# Out:
#              Id  Score                                              Title
# 13041  28018320      0        join in codeigniter returns multiple values  \
# 13060  17597310      0  octave/matlab: create new matrix based on exis...
# 13095  10901520      0  how to loading two parts of the same file to t...
# 13781  23025930     -1  windows how to use the right ctrl key as the l...
# 14669   1143130      1                         dropdownlist items in list
# 14946  30583960      0  best practices for rebase, squashing and incor...
# 15750  16007330      0  ajax load div of one page called from another ...
# 16670  21018500      2  facebook video upload exception "(oauthexcepti...
# 17363  30072410     -1         timestamp splitting incorrect - javascript
# 17589  16920880      3  restkit .20.1 nested array with relationship m...
# 18000  17910080      0       cannot send mail through php mail() function
# 18490  10632520      0  hashlib.sha256 returned some weird characters ...
# 18731   8910050     -1       how to get byte[] array back from md5 string
# 19113  36733300      0       reading a csv file and writing to a csv file
# 19602  27815100      0  parsing and saving csv file in python and csv ...
#
#                                                     Body
# 13041  i have a problem joining two tables. in my fir...  \
# 13060  in octave/matlab, say i have:how would i make ...
# 13095  i have one file (file.csv) filled with integer...
# 13781  i am wondering what should i do to let the win...
# 14669  can anyone tell me shortest way to add all ite...
# 14946  i am new to rebasing.  i have already pushed s...
# 15750  i am facing with some glitches regarding the a...
# 16670  my wpf application i am using facebook c# sdk ...
# 17363  i have a timestamp loaded from mssql into a we...
# 17589  i am having trouble with restkit and mapping t...
# 18000  i tried to send an email through php mail() fu...
# 18490  in javascript the code below returned eec097af...
# 18731    possible duplicate:  is it possible to decry...
# 19113  here is my code, i am trying to read a csv and...
# 19602  this script is meant to parse and sort a list ...
#
#                                                SimilarTo
# 13041                     {30419690: 0.7409016313750877}
# 13060                     {22959390: 0.7104194925966363}
# 13095                     {22959390: 0.7192533941946715}
# 13781                      {9154270: 0.7233997503802955}
# 14669                     {30772210: 0.7298205377060533}
# 14946                     {35104610: 0.7054175562614433}
# 15750                     {16050620: 0.7697189645496809}
# 16670  {9714150: 0.8787714108752057, 14834780: 0.8471...
# 17363  {30419690: 0.7304779143096128, 19772820: 0.726...
# 17589  {9714150: 0.8166481829329381, 14834780: 0.7877...
# 18000                     {32548300: 0.7991494278693998}
# 18490                     {24158810: 0.8351285685110357}
# 18731                      {9396590: 0.7004291615260755}
# 19113                     {27815100: 0.7346225820561673}
# 19602                     {36733300: 0.7346225820561673}

# %%
filtered_similar_questions_df.size
# Out:
# 205

# %%
filtered_similar_questions_df.size/questions_df.size * 100
# Out:
# 0.20500000000000002

# %% [markdown]
# Após testar nossa função em diferentes samplings, percebemos que a porcentagem de perguntas similares em relação ao total de perguntas é muito baixa, o que nos leva a crer que o problema de perguntas duplicadas não é tão grande quanto imaginávamos, ou que o fato de termos reduzido o dataset para menos de 10% do original tenha influenciado nesse resultado.
#
# Outro ponto importante é que a função não leva em consideração a similaridade entre as respostas, pois uma pergunta pode ser considerada duplicada mesmo tendo respostas diferentes, o que pode ser um problema para o usuário que está procurando uma resposta diferente para sua pergunta. Considerar as respostas no cálculo também afetaria no desempenho da função, pois teríamos que calcular a similaridade entre todas as respostas das perguntas similares, o que aumentaria o tempo de execução e recursos usados, resaltando que com apenas menos de 10% do dataset original, o tempo e recursos gastos para calcular a similaridade já é muito alto (utilizar mais do que 25.000 questões ultrapassa 16Gb de memória RAM).
#
# Através desse estudo, podemos chegar as seguintes conclusões:
#
# O stackoverflow é conhecido por tem um moderação muito forte, o que pode ser um dos motivos para a baixa porcentagem de perguntas duplicadas, já que muitas perguntas duplicadas são fechadas pelos moderadores ou até deletadas pelo usuário.
#
# Não é eficiente calcular a similaridade entre todas as perguntas, pois o tempo de execução é muito alto. Uma possível solução seria utilizar as tags das perguntas para filtrar e após isso calcular a similaridade entre perguntas que compartilham tags similares.
#
# Técnicas de filtragem utilizando score da pergunta ou data de fechamento da pergunta podem ser utilizadas para filtrar, já que perguntas duplicadas tendem a ter um score menor e serem fechadas mais rapidamente. Mas, é possível que a pergunta original tenha um score alto e a duplicada tenha um score baixo, o que pode ser um problema para essa solução, já que a pergunta original não entrara nesse novo dataset filtrado.
